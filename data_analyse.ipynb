# %%
from helpers import plot_gait_motion

# %% [markdown]
# We'll first start with evaluating one person individually.

# %%
names = ["Maud", "rosanne", "siebren", "anne"]

comf = "_comf_010001.xlsx"
L_025 = "_roll_025_L_010001.xlsx"
L_050 = "_roll_050_L_010001.xlsx"
L_075 = "_roll_075_L_010001.xlsx"
R_075 = "_roll_075_R_010001.xlsx"

data_sheets = [comf, L_025, L_050, L_075, R_075]

left_kneeflex = "Moment LKneeFlex"
left_kneerot = "Moment LKneeRot"
left_kneerabad = "Moment LKneeAbAd"

# %%
plot_gait_motion(names, data_sheets, motion=left_kneeflex, leg='L', plot_std=True, cohort=True)
# Out:
# ===== Moment LKneeFlex cohort variability (averaged over 4 subjects) =====
# Error reading 'anne_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': Worksheet named 'Moment LKneeFlex comf' not found
# Error reading 'anne_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': Worksheet named 'Moment LKneeFlex comf' not found
# comf: cohort mean std 0.0614
# 0.25L: cohort mean std 0.0677
# 0.50L: cohort mean std 0.0814
# 0.75L: cohort mean std 0.1081
# 0.75R: cohort mean std 0.1359

# %%
plot_gait_motion(names, data_sheets, motion=left_kneeflex)
# Out:
# ===== Moment LKneeFlex variability Maud =====
# comf: 0.0582
# 0.25L: 0.0661
# 0.50L: 0.0801
# 0.75L: 0.0933
# 0.75R: 0.1281
# ===== Moment LKneeFlex variability rosanne =====
# comf: 0.0571
# 0.25L: 0.0656
# 0.50L: 0.0854
# 0.75L: 0.1090
# 0.75R: 0.1453
# ===== Moment LKneeFlex variability siebren =====
# comf: 0.0690
# 0.25L: 0.0748
# 0.50L: 0.0824
# 0.75L: 0.1141
# 0.75R: 0.1504
# ===== Moment LKneeFlex variability anne =====
# 0.25L: 0.0637
# 0.25L: 0.0643
# 0.50L: 0.0775
# 0.75L: 0.1158
# 0.75R: 0.1278

# %%
plot_gait_motion(names, data_sheets, motion=left_kneerot)
# Out:
# ===== Moment LKneeRot variability Maud =====
# comf: 0.0526
# 0.25L: 0.2258
# 0.50L: 0.4582
# 0.75L: 0.6573
# 0.75R: 0.8289
# ===== Moment LKneeRot variability rosanne =====
# comf: 0.0580
# 0.25L: 0.3412
# 0.50L: 0.5614
# 0.75L: 0.6968
# 0.75R: 0.8690
# ===== Moment LKneeRot variability siebren =====
# comf: 0.0591
# 0.25L: 0.3358
# 0.50L: 0.5672
# 0.75L: 0.7564
# 0.75R: 0.8530
# ===== Moment LKneeRot variability anne =====
# 0.25L: 0.0492
# 0.25L: 0.2241
# 0.50L: 0.4254
# 0.75L: 0.7284
# 0.75R: 0.7644

# %%
plot_gait_motion(names, data_sheets, motion=left_kneerabad, leg='L', plot_std=True, cohort=True)
# Out:
# ===== Moment LKneeAbAd cohort variability (averaged over 4 subjects) =====
# Error reading 'anne_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': Worksheet named 'Moment LKneeAbAd comf' not found
# Error reading 'anne_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': Worksheet named 'Moment LKneeAbAd comf' not found
# comf: cohort mean std 0.0373
# 0.25L: cohort mean std 0.1381
# 0.50L: cohort mean std 0.2341
# 0.75L: cohort mean std 0.3192
# 0.75R: cohort mean std 0.4388

# %%
plot_gait_motion(names, data_sheets, motion=left_kneerabad, leg='L', plot_std=True, cohort=False)
# Out:
# ===== Moment LKneeAbAd variability Maud =====
# comf: 0.0349
# 0.25L: 0.1051
# 0.50L: 0.1984
# 0.75L: 0.2830
# 0.75R: 0.4300
# ===== Moment LKneeAbAd variability rosanne =====
# comf: 0.0355
# 0.25L: 0.1536
# 0.50L: 0.2610
# 0.75L: 0.3120
# 0.75R: 0.4681
# ===== Moment LKneeAbAd variability siebren =====
# comf: 0.0416
# 0.25L: 0.1816
# 0.50L: 0.2673
# 0.75L: 0.3254
# 0.75R: 0.4803
# ===== Moment LKneeAbAd variability anne =====
# 0.25L: 0.0352
# 0.25L: 0.1124
# 0.50L: 0.2095
# 0.75L: 0.3565
# 0.75R: 0.3769
