# %%
from helpers import plot_gait_motion

# %% [markdown]
# We'll first start with evaluating one person individually.

# %%
names = ["Maud", "rosanne", "siebren", "anne"]

comf = "_comf_010001.xlsx"
L_025 = "_roll_025_L_010001.xlsx"
L_050 = "_roll_050_L_010001.xlsx"
L_075 = "_roll_075_L_010001.xlsx"
R_075 = "_roll_075_R_010001.xlsx"

data_sheets = [comf, L_025, L_050, L_075, R_075]

kneeflex = "Moment KneeFlex"
kneerot = "Moment KneeRot"
kneerabad = "Moment KneeAbAd"

# %%
plot_gait_motion(names, data_sheets, motion=kneeflex, leg=None, plot_std=True, cohort=True)
# Out:
# ===== Moment KneeFlex cohort variability (averaged over 4 subjects) =====

# %%
plot_gait_motion(names, data_sheets, motion=kneeflex, anonimity=True)
# Out:
# ===== Moment KneeFlex variability p001 =====
# comf: 0.0582
# 0.25L: 0.0661
# 0.50L: 0.0801
# 0.75L: 0.0933
# 0.75R: 0.1047
# ===== Moment KneeFlex variability p002 =====
# comf: 0.0571
# 0.25L: 0.0656
# 0.50L: 0.0854
# 0.75L: 0.1090
# 0.75R: 0.1294
# ===== Moment KneeFlex variability p003 =====
# comf: 0.0690
# 0.25L: 0.0748
# 0.50L: 0.0824
# 0.75L: 0.1141
# 0.75R: 0.1314
# ===== Moment KneeFlex variability p004 =====
# comf: 0.0637
# 0.25L: 0.0643
# 0.50L: 0.0775
# 0.75L: 0.1158
# 0.75R: 0.1113

# %%
plot_gait_motion(names, data_sheets, motion=kneerot, leg=None, plot_std=True, cohort=True)
# Out:
# ===== Moment KneeRot cohort variability (averaged over 4 subjects) =====

# %%
plot_gait_motion(names, data_sheets, motion=kneerot, anonimity=True)
# Out:
# ===== Moment KneeRot variability p001 =====
# comf: 0.0526
# 0.25L: 0.2258
# 0.50L: 0.4582
# 0.75L: 0.6573
# 0.75R: 0.8247
# ===== Moment KneeRot variability p002 =====
# comf: 0.0580
# 0.25L: 0.3412
# 0.50L: 0.5614
# 0.75L: 0.6968
# 0.75R: 0.9243
# ===== Moment KneeRot variability p003 =====
# comf: 0.0591
# 0.25L: 0.3358
# 0.50L: 0.5672
# 0.75L: 0.7564
# 0.75R: 0.8878
# ===== Moment KneeRot variability p004 =====
# comf: 0.0492
# 0.25L: 0.2241
# 0.50L: 0.4254
# 0.75L: 0.7284
# 0.75R: 0.7655

# %%
plot_gait_motion(names, data_sheets, motion=kneerabad, leg=None, plot_std=True, cohort=True)
# Out:
# ===== Moment KneeAbAd cohort variability (averaged over 4 subjects) =====

# %%
plot_gait_motion(names, data_sheets, motion=kneerabad, leg=None, plot_std=True, cohort=False, anonimity=True)
# Out:
# ===== Moment KneeAbAd variability p001 =====
# comf: 0.0349
# 0.25L: 0.1051
# 0.50L: 0.1984
# 0.75L: 0.2830
# 0.75R: 0.3462
# ===== Moment KneeAbAd variability p002 =====
# comf: 0.0355
# 0.25L: 0.1536
# 0.50L: 0.2610
# 0.75L: 0.3120
# 0.75R: 0.4461
# ===== Moment KneeAbAd variability p003 =====
# comf: 0.0416
# 0.25L: 0.1816
# 0.50L: 0.2673
# 0.75L: 0.3254
# 0.75R: 0.4028
# ===== Moment KneeAbAd variability p004 =====
# comf: 0.0352
# 0.25L: 0.1124
# 0.50L: 0.2095
# 0.75L: 0.3565
# 0.75R: 0.3332
