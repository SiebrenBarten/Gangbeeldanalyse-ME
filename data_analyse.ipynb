# %%
from Data.helpers import plot_gait_motion

# %% [markdown]
# We'll first start with evaluating one person individually.

# %%
names = ["Maud", "rosanne", "siebren", "anne"]

comf = "_comf_010001.xlsx"
L_025 = "_roll_025_L_010001.xlsx"
L_050 = "_roll_050_L_010001.xlsx"
L_075 = "_roll_075_L_010001.xlsx"
R_075 = "_roll_075_R_010001.xlsx"

data_sheets = [comf, L_025, L_050, L_075, R_075]

left_kneeflex = "Moment LKneeFlex"
left_kneerot = "Moment LKneeRot"
left_kneerabad = "Moment LKneeAbAd"

# %%
plot_gait_motion(names, data_sheets, motion=left_kneeflex, leg='L', plot_std=True, cohort=True)
# Out:
# ===== Moment LKneeFlex cohort variability (averaged over 4 subjects) =====
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# Error reading 'rosanne_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'rosanne_comf_010001.xlsx'
# Error reading 'rosanne_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'rosanne_comf_010001.xlsx'
# Error reading 'siebren_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'siebren_comf_010001.xlsx'
# Error reading 'siebren_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'siebren_comf_010001.xlsx'
# ...

# %%
plot_gait_motion(names, data_sheets, motion=left_kneeflex)
# Out:
# ===== Moment LKneeFlex variability Maud =====
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeFlex comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# comf: nan
# Error reading 'Maud_roll_025_L_010001.xlsx' sheet 'Moment LKneeFlex 0.25L': [Errno 2] No such file or directory: 'Maud_roll_025_L_010001.xlsx'
# 0.25L: nan
# Error reading 'Maud_roll_050_L_010001.xlsx' sheet 'Moment LKneeFlex 0.50L': [Errno 2] No such file or directory: 'Maud_roll_050_L_010001.xlsx'
# 0.50L: nan
# Error reading 'Maud_roll_075_L_010001.xlsx' sheet 'Moment LKneeFlex 0.75L': [Errno 2] No such file or directory: 'Maud_roll_075_L_010001.xlsx'
# 0.75L: nan
# Error reading 'Maud_roll_075_R_010001.xlsx' sheet 'Moment LKneeFlex 0.75R': [Errno 2] No such file or directory: 'Maud_roll_075_R_010001.xlsx'
# 0.75R: nan
# /Users/siebr/Documents/Eindhoven University of technology/2025-2026/Clinical Modules 2/Gangbeeld analyse/helpers.py:128: RuntimeWarning: Mean of empty slice
# ...

# %%
plot_gait_motion(names, data_sheets, motion=left_kneerot)
# Out:
# ===== Moment LKneeRot variability Maud =====
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeRot comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# comf: nan
# Error reading 'Maud_roll_025_L_010001.xlsx' sheet 'Moment LKneeRot 0.25L': [Errno 2] No such file or directory: 'Maud_roll_025_L_010001.xlsx'
# 0.25L: nan
# Error reading 'Maud_roll_050_L_010001.xlsx' sheet 'Moment LKneeRot 0.50L': [Errno 2] No such file or directory: 'Maud_roll_050_L_010001.xlsx'
# 0.50L: nan
# Error reading 'Maud_roll_075_L_010001.xlsx' sheet 'Moment LKneeRot 0.75L': [Errno 2] No such file or directory: 'Maud_roll_075_L_010001.xlsx'
# 0.75L: nan
# Error reading 'Maud_roll_075_R_010001.xlsx' sheet 'Moment LKneeRot 0.75R': [Errno 2] No such file or directory: 'Maud_roll_075_R_010001.xlsx'
# 0.75R: nan
# ===== Moment LKneeRot variability rosanne =====
# ...

# %%
plot_gait_motion(names, data_sheets, motion=left_kneerabad, leg='L', plot_std=True, cohort=True)
# Out:
# ===== Moment LKneeAbAd cohort variability (averaged over 4 subjects) =====
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# Error reading 'rosanne_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'rosanne_comf_010001.xlsx'
# Error reading 'rosanne_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'rosanne_comf_010001.xlsx'
# Error reading 'siebren_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'siebren_comf_010001.xlsx'
# Error reading 'siebren_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'siebren_comf_010001.xlsx'
# ...

# %%
plot_gait_motion(names, data_sheets, motion=left_kneerabad, leg='L', plot_std=True, cohort=False)
# Out:
# ===== Moment LKneeAbAd variability Maud =====
# Error reading 'Maud_comf_010001.xlsx' sheet 'Moment LKneeAbAd comf': [Errno 2] No such file or directory: 'Maud_comf_010001.xlsx'
# comf: nan
# Error reading 'Maud_roll_025_L_010001.xlsx' sheet 'Moment LKneeAbAd 0.25L': [Errno 2] No such file or directory: 'Maud_roll_025_L_010001.xlsx'
# 0.25L: nan
# Error reading 'Maud_roll_050_L_010001.xlsx' sheet 'Moment LKneeAbAd 0.50L': [Errno 2] No such file or directory: 'Maud_roll_050_L_010001.xlsx'
# 0.50L: nan
# Error reading 'Maud_roll_075_L_010001.xlsx' sheet 'Moment LKneeAbAd 0.75L': [Errno 2] No such file or directory: 'Maud_roll_075_L_010001.xlsx'
# 0.75L: nan
# Error reading 'Maud_roll_075_R_010001.xlsx' sheet 'Moment LKneeAbAd 0.75R': [Errno 2] No such file or directory: 'Maud_roll_075_R_010001.xlsx'
# 0.75R: nan
# ===== Moment LKneeAbAd variability rosanne =====
# ...
